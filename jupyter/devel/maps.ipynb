# %%
import numpy as np

npz = np.load('../data/belgium_maps.npz')
images = npz['x_train']

images = np.mean(images, -1) # convert to gray
factor = 1 / (np.amax(images) - np.amin(images)) # normalization
images = (images - np.amin(images)) * factor

print('shape:     ', images.shape)
print('min value: ', np.amin(images))
print('max value: ', np.amax(images))
# Out:
# shape:      (607, 256, 256)
# min value:  0.0
# max value:  1.0

# %%
r = images.shape[1] / 2
r2 = r * r

for i in range(images.shape[0]):
    for j in range(images.shape[1]):
        for k in range(images.shape[2]):
            if ((j - r)*(j - r) + (k - r)*(k - r) >= r2):
                images[i,j,k] = 0.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i])
    plt.xlabel(i)

# %%
import math
import pink

som_dim = 6
neuron_dim = images.shape[1]

np_som = np.random.rand(som_dim, som_dim, neuron_dim, neuron_dim).astype(np.float32)
som = pink.SOM(np_som)

data = [pink.Data(images[i]) for i in range(len(images))]

trainer = pink.Trainer(som, pink.GaussianFunctor(1.1, 0.2),
                       number_of_rotations=180)

# %%
from tqdm import tqdm_notebook

for iter in tqdm_notebook(range(1), desc="epoch"):
    #for i in tqdm_notebook(range(len(images)), desc="train", leave=False):
    for i in range(1):
        trainer(data[i])
# Out:
# HBox(children=(IntProgress(value=0, description='epoch', max=1, style=ProgressStyle(description_width='initial…

# %%
trainer.update_som()
np_som = np.array(som, copy=True)

plt.figure(figsize=(20,20))
plt.imshow(np_som.swapaxes(1, 2).reshape((som_dim * neuron_dim, som_dim * neuron_dim)))
plt.grid(False)
